# %% [markdown]
# # 08 — Embedding Geometry & Representation Analysis
#
# Transformer embeddings exhibit rich geometric structure.
#
# ### What we'll explore
# - PCA and t-SNE visualizations
# - Token similarity and cosine distances
# - Clustering in embedding space
